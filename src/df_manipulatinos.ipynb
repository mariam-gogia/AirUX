# %%
# data structure and manipulation
import pandas as pd
import numpy as np 

# data visualization
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib.animation import FuncAnimation

# files and time 
import csv
import sys
import time
import datetime as dt

# %%
# import data
file = 'data.csv'
df = pd.read_csv(file)
df.head(100)
# Out:
#      id         r  theta      phi  acc_x  acc_y   acc_z  delta_r  delta_theta  \
# 0     1   976.190  5.310  -95.079   -8.0  -90.0   972.0    0.000        0.000
# 1     2   974.741  7.679  -75.323   33.0 -126.0   966.0   -1.449        2.369
# 2     3  1012.020  6.752  -61.927   56.0 -105.0  1005.0   37.279       -0.927
# 3     4  1006.702  7.961  -59.388   71.0 -120.0   997.0   -5.318        1.209
# 4     5   999.253  6.413  -67.340   43.0 -103.0   993.0   -7.449       -1.548
# ..  ...       ...    ...      ...    ...    ...     ...      ...          ...
# 95   96  1015.563  6.517  -86.020    8.0 -115.0  1009.0   -5.379       -0.634
# 96   97  1001.657  7.962  -99.122  -22.0 -137.0   992.0  -13.906        1.445
# 97   98  1005.549  7.025  -79.695   22.0 -121.0   998.0    3.892       -0.937
# 98   99  1014.303  6.879  -95.194  -11.0 -121.0  1007.0    8.754       -0.146
# 99  100  1028.588  5.975 -101.309  -21.0 -105.0  1023.0   14.285       -0.904
#
#     delta_phi  delta_acc_x  delta_acc_y  delta_acc_z label
# 0       0.000          0.0          0.0          0.0   NaN
# 1      19.756         41.0        -36.0        -36.0   NaN
# 2      13.396         23.0         21.0         21.0   NaN
# 3       2.539         15.0        -15.0        -15.0   NaN
# 4      -7.952        -28.0         17.0         17.0   NaN
# ..        ...          ...          ...          ...   ...
# 95     14.405         31.0         10.0         10.0   NaN
# 96    -13.102        -30.0        -22.0        -22.0   NaN
# 97     19.427         44.0         16.0         16.0   NaN
# 98    -15.499        -33.0          0.0          0.0   NaN
# 99     -6.115        -10.0         16.0         16.0   NaN
#
# [100 rows x 14 columns]

# %%
time_steps = df['id']

angles_values = {
    "radius": df['r'], 
    "theta": df['theta'], 
    "phi": df['phi'],  
}

acceleration_values = {
    "acc_x": df['acc_x'], 
    "acc_y": df['acc_y'], 
    "acc_z": df['acc_z'],    
}

change_values = {
    "delta_r": df['delta_r'], 
    "delta_theta": df['delta_theta'], 
    "delta_phi": df['delta_phi'], 
    "delta_acc_x": df['delta_acc_x'], 
    "delta_acc_y": df['delta_acc_y'], 
    "delta_acc_z": df['delta_acc_z'], 
}

# %%
# visualization functions
def visualize_separetly(values):
    for value in values:
        plt.plot(time_steps, values[value], linewidth=0.5, label=value)    
        plt.title("Signal Visualization", color="white")
        plt.xlabel("Time Steps", color='white')
        plt.ylabel(value, color="white")
        plt.legend()
        plt.show()
        
def visualize_together(values):
    for value in values:
        plt.plot(time_steps, values[value], linewidth=0.5, label=value)    
        plt.title("Signal Visualization", color="white")
        plt.xlabel("Time Steps", color='white')
        plt.ylabel(value, color="white")
        plt.legend()
    plt.show()

# %%
# visualization
visualize_together(angles_values)
visualize_together(acceleration_values)
visualize_together(change_values)

# %%
visualize_separetly(change_values)

# %%
visualize_separetly(acceleration_values)
